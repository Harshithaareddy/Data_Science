# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshithaareddy/Data_Science/blob/main/21BDS0294.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **EXPLORATORY DATA ANALYSIS THEROY ASSIGNMENT**

# %% [markdown]
# **Name: Basi reddy Harshitha reddy**
#
# **Registration Number: 21BDS0294**

# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Dataset URL
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/employee_promotion.csv"

# Loading the dataset into a DataFrame
df = pd.read_csv(url)

# Displaying the first few rows
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings age  previous_year_rating  \
# 0            sourcing                1  35                   5.0
# 1               other                1  30                   5.0
# 2            sourcing                1  34                   3.0
# 3               other                2  39                   1.0
# 4               other                1  45                   3.0
#
#    length_of_service  awards_won  avg_training_score is_promoted
# 0                  8         0.0                49.0           0
# ...

# %%
# Dimensions of the dataset
print("Dataset Dimensions (Rows, Columns):", df.shape)
# Out:
# Dataset Dimensions (Rows, Columns): (54808, 13)

# %%
# Displaying column names
print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['employee_id', 'department', 'region', 'education', 'gender', 'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'awards_won', 'avg_training_score', 'is_promoted']

# %%
# Checking datatypes
print("Datatype of columns")
print(df.dtypes)
# Out:
# Datatype of columns
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                      object
# previous_year_rating    float64
# length_of_service         int64
# awards_won              float64
# avg_training_score      float64
# is_promoted              object
# dtype: object

# %%
# Checking for missing values in each column
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won                 1
# avg_training_score      2561
# is_promoted                0
# dtype: int64

# %%
# Summary statistics for numerical columns
print("\nSummary Statistics for Numerical Features:")
print(df.describe())
# Out:
# Summary Statistics for Numerical Features:
#         employee_id  no_of_trainings  previous_year_rating  length_of_service  \
# count  54808.000000     54808.000000          50684.000000       54808.000000
# mean   39195.830627         1.253011              3.329256           5.865512
# std    22586.581449         0.609264              1.259993           4.265094
# min        1.000000         1.000000              1.000000           1.000000
# 25%    19669.750000         1.000000              3.000000           3.000000
# 50%    39225.500000         1.000000              3.000000           5.000000
# 75%    58730.500000         1.000000              4.000000           7.000000
# max    78298.000000        10.000000              5.000000          37.000000
#
#          awards_won  avg_training_score
# count  54807.000000        52247.000000
# mean       0.023172           63.712347
# std        0.150452           13.522016
# min        0.000000           39.000000
# ...

# %%
# Summary of categorical features
print("\nSummary Statistics for Categorical Features:")
print(df.describe(include=['object']))
# Out:
# Summary Statistics for Categorical Features:
#                department    region   education gender recruitment_channel  \
# count               54808     54808       52399  54808               54808
# unique                  9        34           4      2                   4
# top     Sales & Marketing  region_2  Bachelor's      m               other
# freq                16840     12343       36668  38496               30445
#
#           age is_promoted
# count   54808       54808
# unique     42           3
# top        30           0
# freq     3665       50139

# %%
# Checking unique values in categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f"\nUnique values in '{col}':")
    print(df[col].unique())
# Out:
# Unique values in 'department':
# ['Sales & Marketing' 'Operations' 'Technology' 'Analytics' 'R&D'
#  'Procurement' 'Finance' 'HR' 'Legal']
#
# Unique values in 'region':
# ['region_7' 'region_22' 'region_19' 'region_23' 'region_26' 'region_2'
#  'region_20' 'region_34' 'region_1' 'region_4' 'region_29' 'region_31'
#  'region_15' 'region_14' 'region_11' 'region_5' 'region_28' 'region_17'
#  'region_13' 'region_16' 'region_25' 'region_10' 'region_27' 'region_30'
#  'region_12' 'region_21' 'region_8' 'region_32' 'region_6' 'region_33'
#  'region_24' 'region_3' 'region_9' 'region_18']
#
# Unique values in 'education':
# ["Master's & above" "Bachelor's" nan '?' 'Below Secondary']
#
# Unique values in 'gender':
# ['f' 'm']
#
# Unique values in 'recruitment_channel':
# ['sourcing' 'other' 'referred' '?']
#
# Unique values in 'age':
# ['35' '30' '34' '39' '45' '31' '33' '28' '32' '49' '37' '38' '41' '27'
#  '29' '26' '24' '57' '40' '42' '23' '59' '44' '50' '56' '20' '25' '47'
# ...

# %%
# Dropping rows with missing data
df_cleaned = df.dropna()
print(df_cleaned.isnull().sum())
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# awards_won              0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
# Filling missing data
df_filled = df.fillna(method='ffill')
print("\nData after forward fill:")
print(df_filled.head())
# Out:
# Data after forward fill:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings age  previous_year_rating  \
# 0            sourcing                1  35                   5.0
# 1               other                1  30                   5.0
# 2            sourcing                1  34                   3.0
# 3               other                2  39                   1.0
# 4               other                1  45                   3.0
#
#    length_of_service  awards_won  avg_training_score is_promoted
# ...

# %% [markdown]
# ## **MODULE - 2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import KBinsDiscretizer

# 1. Loading the Dataset
url = 'https://raw.githubusercontent.com/salemprakash/EDA/main/Data/employee_promotion.csv'
df = pd.read_csv(url)
print("First 5 rows of the dataset:")
print(df.head())

# 2. Data Deduplication
print("\nShape before deduplication:", df.shape)
df_deduped = df.drop_duplicates()
print("Shape after deduplication:", df_deduped.shape)

# 3. Replacing Values
df_replaced = df.copy()

# Replace NaN values with a specific value
df_replaced['education'].fillna(df_replaced['education'].mode()[0])  # Fill NaN in 'education' with mode
df_replaced['age'] = pd.to_numeric(df_replaced['age'], errors='coerce')  # Convert 'age' to numeric and fill NaN with mean
df_replaced['age'].fillna(df_replaced['age'].mean())
print("\nEducation and Age columns after replacing NaN with mode/mean:")
print(df_replaced[['education', 'age']].head())

# 4. Discretization and Binning
# Bin 'age' column into categories
df_binned = df.copy()
# Convert 'age' column to numeric, handling errors by coercing to NaN
df_binned['age'] = pd.to_numeric(df_binned['age'], errors='coerce')
df_binned['age_binned'] = pd.cut(df_binned['age'], bins=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])
print("\nBinned 'age' column:")
print(df_binned[['age', 'age_binned']].head())

# 5. Handling Missing Data - Traditional Method (Maximum Likelihood Estimation)
# Introduce some missing values for demonstration
df_with_na = df.copy()
df_with_na.loc[10:15, 'previous_year_rating'] = np.nan  # Creating missing values in 'previous_year_rating'

# Handle missing data using SimpleImputer (Maximum Likelihood Estimation approximated via mean substitution here)
imputer = SimpleImputer(strategy='mean')
df_with_na['previous_year_rating'] = imputer.fit_transform(df_with_na[['previous_year_rating']])
print("\nPrevious Year Rating column after imputing missing values using MLE approximation (mean):")
print(df_with_na[['previous_year_rating']].head(20))

# 6. Discretization with KBinsDiscretizer
kbins = KBinsDiscretizer(n_bins=4, encode='ordinal', strategy='uniform')
# Impute missing values with the mean of the column before discretization
df['previous_year_rating_binned'] = kbins.fit_transform(df[['previous_year_rating']].fillna(df['previous_year_rating'].mean()))
print("\nDiscretized 'previous_year_rating' column using KBinsDiscretizer:")
print(df[['previous_year_rating', 'previous_year_rating_binned']].head())

# 7. Visualizing Binned Data
plt.figure(figsize=(10, 6))
# Access the 'age_binned' column from the correct DataFrame (df_binned)
df_binned['age_binned'].value_counts().plot(kind='bar')
plt.title('Distribution of Age Bins')
plt.xlabel('Age Bins')
plt.ylabel('Frequency')
plt.show()
# Out:
# First 5 rows of the dataset:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings age  previous_year_rating  \
# 0            sourcing                1  35                   5.0
# 1               other                1  30                   5.0
# 2            sourcing                1  34                   3.0
# 3               other                2  39                   1.0
# 4               other                1  45                   3.0
#
#    length_of_service  awards_won  avg_training_score is_promoted
# ...

# %% [markdown]
# ## **MODULE - 3**

# %%
# Set style for plots
sns.set_style("darkgrid")

# %% [markdown]
# # **Univariate Analysis**

# %%
df_cleaned['age'] = pd.to_numeric(df_cleaned['age'], errors='coerce')

# %%
# Distribution of numerical variables
numerical_columns = ['age', 'no_of_trainings', 'previous_year_rating', 'length_of_service', 'avg_training_score']
df_cleaned[numerical_columns].hist(figsize=(12, 8), bins=20, edgecolor='black')
plt.suptitle("Histograms of Numerical Features", fontsize=16)
plt.show()

# %%
# Boxplot for numerical variables to detect outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_cleaned[numerical_columns])
plt.title("Boxplots of Numerical Features")
plt.xticks(rotation=90)
plt.show()

# %%
# Countplot for categorical variables
categorical_columns = ['department', 'education', 'gender', 'recruitment_channel', 'is_promoted']
plt.figure(figsize=(14, 8))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(2, 3, i)
    sns.countplot(data=df_cleaned, x=col, palette="Set2")
    plt.xticks(rotation = 90)
    plt.title(f"Countplot of {col}")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-ca5e671a3379>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x=col, palette="Set2")
# <ipython-input-22-ca5e671a3379>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x=col, palette="Set2")
# <ipython-input-22-ca5e671a3379>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x=col, palette="Set2")
# <ipython-input-22-ca5e671a3379>:6: FutureWarning:
#
# ...

# %% [markdown]
# # **Bivariate Analysis**

# %%
# Scatter Plot: Age vs Training Score (Colored by Promotion)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_cleaned, x="age", y="avg_training_score", hue="is_promoted", alpha=0.7)
plt.title("Age vs Training Score (Colored by Promotion)")
plt.xlabel("Age")
plt.ylabel("Average Training Score")
plt.legend(title="Promoted")
plt.show()

# %%
# Scatter Plot: Length of Service vs Training Score (Colored by Promotion)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_cleaned, x="length_of_service", y="avg_training_score", hue="is_promoted", alpha=0.7)
plt.title("Length of Service vs Training Score (Colored by Promotion)")
plt.xlabel("Length of Service (Years)")
plt.ylabel("Average Training Score")
plt.legend(title="Promoted")
plt.show()

# %%
# Box Plot: Training Score Distribution Across Departments
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_cleaned, x="department", y="avg_training_score", palette="magma", hue="is_promoted")
plt.xticks(rotation=90)
plt.title("Training Score Distribution Across Departments (By Promotion Status)")
plt.xlabel("Department")
plt.ylabel("Average Training Score")
plt.legend(title="Promoted")
plt.show()

# %%
# Box Plot: Age Distribution by Promotion Status
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_cleaned, x="is_promoted", y="age", palette="coolwarm")
plt.title("Age Distribution by Promotion Status")
plt.xlabel("Promotion Status (0 = Not Promoted, 1 = Promoted)")
plt.ylabel("Age")
plt.show()
# Out:
# <ipython-input-26-57c3b2b38c8a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_cleaned, x="is_promoted", y="age", palette="coolwarm")

# %%
# Box Plot: Previous Year Rating by Promotion Status
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_cleaned, x="is_promoted", y="previous_year_rating", palette="crest")
plt.title("Previous Year Rating Distribution by Promotion Status")
plt.xlabel("Promotion Status")
plt.ylabel("Previous Year Rating")
plt.show()
# Out:
# <ipython-input-27-478df3f87565>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_cleaned, x="is_promoted", y="previous_year_rating", palette="crest")

# %%
# Bar plot (Average Training Score by Department)
plt.figure(figsize=(10, 6))
sns.barplot(data=df_cleaned, x="department", y="avg_training_score", palette="viridis", ci=None)
plt.xticks(rotation=90)
plt.title("Average Training Score by Department")
plt.show()
# Out:
# <ipython-input-28-94a58a15b292>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_cleaned, x="department", y="avg_training_score", palette="viridis", ci=None)
# <ipython-input-28-94a58a15b292>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_cleaned, x="department", y="avg_training_score", palette="viridis", ci=None)

# %% [markdown]
# # **Multivariate Analysis**

# %%
# Pairplot to explore multiple relationships
sns.pairplot(df_cleaned, hue="is_promoted", diag_kind="kde", palette="husl")
plt.show()

# %%
# Violin plot (Age vs Promotion)
plt.figure(figsize=(8, 6))
sns.violinplot(data=df_cleaned, x="is_promoted", y="age", palette="Set2")
plt.title("Age Distribution by Promotion Status")
plt.show()
# Out:
# <ipython-input-30-d81d9191fd31>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_cleaned, x="is_promoted", y="age", palette="Set2")

# %%
correlation = df_cleaned.corr(method='pearson', numeric_only=True)
correlation
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.006439  0.000182
# no_of_trainings         -0.006439         1.000000 -0.084928
# age                      0.000182        -0.084928  1.000000
# previous_year_rating     0.004040        -0.064412  0.004843
# length_of_service        0.002483        -0.056417  0.620456
# awards_won               0.008185        -0.009463 -0.012337
# avg_training_score       0.001025         0.043320 -0.067143
#
#                       previous_year_rating  length_of_service  awards_won  \
# employee_id                       0.004040           0.002483    0.008185
# no_of_trainings                  -0.064412          -0.056417   -0.009463
# age                               0.004843           0.620456   -0.012337
# previous_year_rating              1.000000          -0.000139    0.029482
# length_of_service                -0.000139           1.000000   -0.043481
# ...

# %%
# Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
